# %% [markdown]
# <a href="https://colab.research.google.com/github/pilaribanez/Datavision/blob/main/Python_ejercicios%20(1%2C2%2C3%2C4).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Big Data
# # Introducción a Python

# %% [markdown]
# ## 1) Primer Paso
#
# Este es un primer ejercicio de python

# %%
a=1+1

# %%
a
# Out:
# 2

# %%
print(a)
# Out:
# 2

# %%
b="Big Data"

# %%
b
# Out:
# 'Big Data'

# %% [markdown]
# ## Segundo paso!
#
# Explorar un pandas data frame y sus tipos de datos

# %%
# cargar librería Pandas

# %%
import pandas as pd

# %%
# crear data frame (no le presten atención por ahora...)
d_star_wars = pd.DataFrame({'personaje': ['Luke Skywaker', 'C-3PO', 'Darth Vader'], 'altura':[172, 167, 202]})

# %%
d_star_wars
# Out:
#        personaje  altura
# 0  Luke Skywaker     172
# 1          C-3PO     167
# 2    Darth Vader     202

# %%
# Tipos de datos de pandas data frame
d_star_wars.dtypes
# Out:
# personaje    object
# altura        int64
# dtype: object

# %%
# Tipo de estructura de dato: la lista
lista_personajes=['Luke Skywaker', 'C-3PO', 'Darth Vader']

# %%
lista_personajes
# Out:
# ['Luke Skywaker', 'C-3PO', 'Darth Vader']

# %%
lista_altura=[172, 167, 202]

# %%
lista_altura
# Out:
# [172, 167, 202]

# %%
# Crear un pandas dataframe basado en 2 listas
dataframe_2l = pd.DataFrame({'personaje': lista_personajes,
                   'altura':lista_altura
                  })

# %%
dataframe_2l
# Out:
#        personaje  altura
# 0  Luke Skywaker     172
# 1          C-3PO     167
# 2    Darth Vader     202

# %% [markdown]
# ## Tercer paso!
#
# Filtrar datos en pandas. La lógica de la notación vectorial.

# %%
d_star_wars
# Out:
#        personaje  altura
# 0  Luke Skywaker     172
# 1          C-3PO     167
# 2    Darth Vader     202

# %%
d_star_wars['personaje'] # devuelve un pandas series
# Out:
# 0    Luke Skywaker
# 1            C-3PO
# 2      Darth Vader
# Name: personaje, dtype: object

# %%
# d_star_wars.iloc[indice de fila, indice de columna]
d_star_wars.iloc[:, 0] # los dos puntos simboliza los slides
# Out:
# 0    Luke Skywaker
# 1            C-3PO
# 2      Darth Vader
# Name: personaje, dtype: object

# %%
# devuelve todo el registro 0
d_star_wars.iloc[0, :]
# Out:
# personaje    Luke Skywaker
# altura                 172
# Name: 0, dtype: object

# %% [markdown]
# Esto los puede confundir...

# %%
d_star_wars.loc[:, 'personaje'] # es equivalente a: d_star_wars.iloc[:, 0]
# Out:
# 0    Luke Skywaker
# 1            C-3PO
# 2      Darth Vader
# Name: personaje, dtype: object

# %%
#d_star_wars.iloc[:, 'personaje'] # error porque el 2do parámetro no es un entero

# %%
# índices para las columnas:
d_star_wars.columns
# Out:
# Index(['personaje', 'altura'], dtype='object')

# %%
# índices de los registros
list(d_star_wars.index)
# Out:
# [0, 1, 2]

# %%
d_star_wars.loc[0, :] # es equivalente: d_star_wars.iloc[0, :] (porque el índice 0 es la posición y el nombre)
# Out:
# personaje    Luke Skywaker
# altura                 172
# Name: 0, dtype: object

# %%
# acceder a 1 elemento
d_star_wars.loc[0, 'altura']
# Out:
# np.int64(172)

# %%
d_star_wars.loc[1, 'altura']
# Out:
# np.int64(167)

# %% [markdown]
# ## Cuarto paso
#
# Un poco mas de acceso y filtos de datos con condiciones

# %% [markdown]
# ![](https://shanelynnwebsite-mid9n9g1q9y8tt.netdna-ssl.com/wp-content/uploads/2016/10/Pandas-selections-and-indexing-768x549.png)

# %%
d_star_wars
# Out:
#        personaje  altura
# 0  Luke Skywaker     172
# 1          C-3PO     167
# 2    Darth Vader     202

# %%
d_star_wars.iloc[0:2, 0] #[indice de fila, indice de columna] 0:2 significa que queremos la fila desde la posición 0 a la 2
# Out:
# 0    Luke Skywaker
# 1            C-3PO
# Name: personaje, dtype: object

# %%
# en este caso, nos devuelve todo
d_star_wars.iloc[0:3, 0:2]
# Out:
#        personaje  altura
# 0  Luke Skywaker     172
# 1          C-3PO     167
# 2    Darth Vader     202

# %% [markdown]
# ### Remplazar valores

# %%
# otra manera de filtrar vectorialmente
d_star_wars['personaje']=='Darth Vader'
# Out:
# 0    False
# 1    False
# 2     True
# Name: personaje, dtype: bool

# %%
# ¿Cómo le cambiamos la altura a Darth Vader?
v_flag = d_star_wars['personaje']=='Darth Vader'

# %%
# ¿Como remplazar un valor basado en una condición?
d_star_wars.loc[v_flag, 'altura']
# Out:
# 2    202
# Name: altura, dtype: int64

# %%
d_star_wars.loc[v_flag, 'altura'] = 185

# %%
# chequeo
d_star_wars
# Out:
#        personaje  altura
# 0  Luke Skywaker     172
# 1          C-3PO     167
# 2    Darth Vader     185

# %%
# haciendo todo en la misma linea
d_star_wars.loc[ d_star_wars['personaje']=='Luke Skywaker', 'altura']=200

# %%
d_star_wars
# Out:
#        personaje  altura
# 0  Luke Skywaker     200
# 1          C-3PO     167
# 2    Darth Vader     185

# %% [markdown]
# ## 2) Dominando los datos
#
# Carga de archivos, exploración de un data frame

# %%
# URL donde se encuentra el archivo CSV
url = 'https://raw.githubusercontent.com/fpineyro/homework-0/master/starwars.csv'

# Lee el CSV
d_star_wars = pd.read_csv(url)

# %%
# Muestra las primeras 5 filas para ver si efectivamente cargó bien lso datos
d_star_wars.head()
# Out:
#              name  height mass hair_color   skin_color eye_color birth_year  \
# 0  Luke Skywalker   172.0   77      blond         fair      blue      19BBY
# 1           C-3PO   167.0   75        NaN         gold    yellow     112BBY
# 2           R2-D2    96.0   32        NaN  white, blue       red      33BBY
# 3     Darth Vader   202.0  136       none        white    yellow    41.9BBY
# 4     Leia Organa   150.0   49      brown        light     brown      19BBY
#
#    gender homeworld species
# 0    male  Tatooine   Human
# 1     NaN  Tatooine   Droid
# 2     NaN     Naboo   Droid
# 3    male  Tatooine   Human
# 4  female  Alderaan   Human

# %% [markdown]
# Cargamos los datos en una tabla

# %%
# Exploración con DataTable colab
from google.colab.data_table import DataTable

DataTable(d_star_wars)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>height</th>
#       <th>mass</th>
#       <th>hair_color</th>
#       <th>skin_color</th>
#       <th>eye_color</th>
#       <th>birth_year</th>
#       <th>gender</th>
#       <th>homeworld</th>
#       <th>species</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Luke Skywalker</td>
#       <td>172.0</td>
#       <td>77</td>
#       <td>blond</td>
#       <td>fair</td>
#       <td>blue</td>
#       <td>19BBY</td>
#       <td>male</td>
#       <td>Tatooine</td>
#       <td>Human</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>C-3PO</td>
#       <td>167.0</td>
#       <td>75</td>
#       <td>NaN</td>
#       <td>gold</td>
#       <td>yellow</td>
#       <td>112BBY</td>
#       <td>NaN</td>
#       <td>Tatooine</td>
#       <td>Droid</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>R2-D2</td>
#       <td>96.0</td>
#       <td>32</td>
#       <td>NaN</td>
#       <td>white, blue</td>
#       <td>red</td>
#       <td>33BBY</td>
#       <td>NaN</td>
#       <td>Naboo</td>
#       <td>Droid</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Darth Vader</td>
#       <td>202.0</td>
#       <td>136</td>
#       <td>none</td>
#       <td>white</td>
#       <td>yellow</td>
#       <td>41.9BBY</td>
#       <td>male</td>
#       <td>Tatooine</td>
#       <td>Human</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Leia Organa</td>
#       <td>150.0</td>
#       <td>49</td>
#       <td>brown</td>
#       <td>light</td>
#       <td>brown</td>
#       <td>19BBY</td>
#       <td>female</td>
#       <td>Alderaan</td>
#       <td>Human</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>82</th>
#       <td>Rey</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>brown</td>
#       <td>light</td>
#       <td>hazel</td>
#       <td>NaN</td>
#       <td>female</td>
#       <td>NaN</td>
#       <td>Human</td>
#     </tr>
#     <tr>
#       <th>83</th>
#       <td>Poe Dameron</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>brown</td>
#       <td>light</td>
#       <td>brown</td>
#       <td>NaN</td>
#       <td>male</td>
#       <td>NaN</td>
#       <td>Human</td>
#     </tr>
#     <tr>
#       <th>84</th>
#       <td>BB8</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>none</td>
#       <td>none</td>
#       <td>black</td>
#       <td>NaN</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>Droid</td>
#     </tr>
#     <tr>
#       <th>85</th>
#       <td>Captain Phasma</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>female</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>86</th>
#       <td>Padmé Amidala</td>
#       <td>165.0</td>
#       <td>45</td>
#       <td>brown</td>
#       <td>light</td>
#       <td>brown</td>
#       <td>46BBY</td>
#       <td>female</td>
#       <td>Naboo</td>
#       <td>Human</td>
#     </tr>
#   </tbody>
# </table>
# <p>87 rows × 10 columns</p>
# </div>

# %%
# shape, nos muestra cuantas filas (87) y cuantas columnas tiene el dataframe (10)
d_star_wars.shape
# Out:
# (87, 10)

# %%
# head / tail
d_star_wars.head(3)
# Out:
#              name  height mass hair_color   skin_color eye_color birth_year  \
# 0  Luke Skywalker   172.0   77      blond         fair      blue      19BBY
# 1           C-3PO   167.0   75        NaN         gold    yellow     112BBY
# 2           R2-D2    96.0   32        NaN  white, blue       red      33BBY
#
#   gender homeworld species
# 0   male  Tatooine   Human
# 1    NaN  Tatooine   Droid
# 2    NaN     Naboo   Droid

# %%
# funpymodeling / instalar nuevas librerías
# !pip install funpymodeling
# Out:
# Requirement already satisfied: funpymodeling in /usr/local/lib/python3.11/dist-packages (0.1.9)
# Requirement already satisfied: flake8<7.0.0,>=6.0.0 in /usr/local/lib/python3.11/dist-packages (from funpymodeling) (6.1.0)
# Requirement already satisfied: jupyter<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from funpymodeling) (1.1.1)
# Requirement already satisfied: matplotlib<4.0.0,>=3.7.1 in /usr/local/lib/python3.11/dist-packages (from funpymodeling) (3.10.0)
# Requirement already satisfied: numpy<2.0.0,>=1.26.2 in /usr/local/lib/python3.11/dist-packages (from funpymodeling) (1.26.4)
# Requirement already satisfied: pandas<3.0.0,>=2.1.4 in /usr/local/lib/python3.11/dist-packages (from funpymodeling) (2.2.2)
# Requirement already satisfied: pre-commit<4.0.0,>=3.3.2 in /usr/local/lib/python3.11/dist-packages (from funpymodeling) (3.8.0)
# Requirement already satisfied: pytest<8.0.0,>=7.3.1 in /usr/local/lib/python3.11/dist-packages (from funpymodeling) (7.4.4)
# Requirement already satisfied: scikit-learn<2.0.0,>=1.2.2 in /usr/local/lib/python3.11/dist-packages (from funpymodeling) (1.6.1)
# Requirement already satisfied: seaborn<0.13.0,>=0.12.2 in /usr/local/lib/python3.11/dist-packages (from funpymodeling) (0.12.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.6.3 in /usr/local/lib/python3.11/dist-packages (from funpymodeling) (4.13.1)
# Requirement already satisfied: mccabe<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from flake8<7.0.0,>=6.0.0->funpymodeling) (0.7.0)
# Requirement already satisfied: pycodestyle<2.12.0,>=2.11.0 in /usr/local/lib/python3.11/dist-packages (from flake8<7.0.0,>=6.0.0->funpymodeling) (2.11.1)
# Requirement already satisfied: pyflakes<3.2.0,>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from flake8<7.0.0,>=6.0.0->funpymodeling) (3.1.0)
# Requirement already satisfied: notebook in /usr/local/lib/python3.11/dist-packages (from jupyter<2.0.0,>=1.0.0->funpymodeling) (6.5.7)
# Requirement already satisfied: jupyter-console in /usr/local/lib/python3.11/dist-packages (from jupyter<2.0.0,>=1.0.0->funpymodeling) (6.1.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.11/dist-packages (from jupyter<2.0.0,>=1.0.0->funpymodeling) (7.16.6)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.11/dist-packages (from jupyter<2.0.0,>=1.0.0->funpymodeling) (6.17.1)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.11/dist-packages (from jupyter<2.0.0,>=1.0.0->funpymodeling) (7.7.1)
# Requirement already satisfied: jupyterlab in /usr/local/lib/python3.11/dist-packages (from jupyter<2.0.0,>=1.0.0->funpymodeling) (4.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4.0.0,>=3.7.1->funpymodeling) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4.0.0,>=3.7.1->funpymodeling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4.0.0,>=3.7.1->funpymodeling) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4.0.0,>=3.7.1->funpymodeling) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4.0.0,>=3.7.1->funpymodeling) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4.0.0,>=3.7.1->funpymodeling) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4.0.0,>=3.7.1->funpymodeling) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4.0.0,>=3.7.1->funpymodeling) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<3.0.0,>=2.1.4->funpymodeling) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<3.0.0,>=2.1.4->funpymodeling) (2025.2)
# Requirement already satisfied: cfgv>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from pre-commit<4.0.0,>=3.3.2->funpymodeling) (3.4.0)
# Requirement already satisfied: identify>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from pre-commit<4.0.0,>=3.3.2->funpymodeling) (2.6.9)
# Requirement already satisfied: nodeenv>=0.11.1 in /usr/local/lib/python3.11/dist-packages (from pre-commit<4.0.0,>=3.3.2->funpymodeling) (1.9.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from pre-commit<4.0.0,>=3.3.2->funpymodeling) (6.0.2)
# Requirement already satisfied: virtualenv>=20.10.0 in /usr/local/lib/python3.11/dist-packages (from pre-commit<4.0.0,>=3.3.2->funpymodeling) (20.30.0)
# Requirement already satisfied: iniconfig in /usr/local/lib/python3.11/dist-packages (from pytest<8.0.0,>=7.3.1->funpymodeling) (2.1.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /usr/local/lib/python3.11/dist-packages (from pytest<8.0.0,>=7.3.1->funpymodeling) (1.5.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<2.0.0,>=1.2.2->funpymodeling) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<2.0.0,>=1.2.2->funpymodeling) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<2.0.0,>=1.2.2->funpymodeling) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib<4.0.0,>=3.7.1->funpymodeling) (1.17.0)
# Requirement already satisfied: distlib<1,>=0.3.7 in /usr/local/lib/python3.11/dist-packages (from virtualenv>=20.10.0->pre-commit<4.0.0,>=3.3.2->funpymodeling) (0.3.9)
# Requirement already satisfied: filelock<4,>=3.12.2 in /usr/local/lib/python3.11/dist-packages (from virtualenv>=20.10.0->pre-commit<4.0.0,>=3.3.2->funpymodeling) (3.18.0)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in /usr/local/lib/python3.11/dist-packages (from virtualenv>=20.10.0->pre-commit<4.0.0,>=3.3.2->funpymodeling) (4.3.7)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.11/dist-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (1.8.0)
# Requirement already satisfied: ipython>=7.23.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (7.34.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.11/dist-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (7.4.9)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.1.7)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.11/dist-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (1.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (5.9.5)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.11/dist-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (24.0.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (6.4.2)
# Requirement already satisfied: traitlets>=5.1.0 in /usr/local/lib/python3.11/dist-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (5.7.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets->jupyter<2.0.0,>=1.0.0->funpymodeling) (3.6.10)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets->jupyter<2.0.0,>=1.0.0->funpymodeling) (3.0.13)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-console->jupyter<2.0.0,>=1.0.0->funpymodeling) (3.0.50)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from jupyter-console->jupyter<2.0.0,>=1.0.0->funpymodeling) (2.18.0)
# Requirement already satisfied: async-lru>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (2.0.5)
# Requirement already satisfied: httpx>=0.25.0 in /usr/local/lib/python3.11/dist-packages (from jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.28.1)
# Requirement already satisfied: jinja2>=3.0.3 in /usr/local/lib/python3.11/dist-packages (from jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (3.1.6)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.11/dist-packages (from jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (5.7.2)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (2.2.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (2.15.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /usr/local/lib/python3.11/dist-packages (from jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in /usr/local/lib/python3.11/dist-packages (from jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.2.4)
# Requirement already satisfied: setuptools>=41.1.0 in /usr/local/lib/python3.11/dist-packages (from jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (75.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->funpymodeling) (4.13.3)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert->jupyter<2.0.0,>=1.0.0->funpymodeling) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.11/dist-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.11/dist-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->funpymodeling) (3.0.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.11/dist-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->funpymodeling) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.10.2)
# Requirement already satisfied: nbformat>=5.7 in /usr/local/lib/python3.11/dist-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->funpymodeling) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->funpymodeling) (1.5.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.11/dist-packages (from notebook->jupyter<2.0.0,>=1.0.0->funpymodeling) (23.1.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from notebook->jupyter<2.0.0,>=1.0.0->funpymodeling) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.11/dist-packages (from notebook->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.11/dist-packages (from notebook->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.21.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.11/dist-packages (from notebook->jupyter<2.0.0,>=1.0.0->funpymodeling) (1.2.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert->jupyter<2.0.0,>=1.0.0->funpymodeling) (1.4.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx>=0.25.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (4.9.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx>=0.25.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.25.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (1.0.7)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx>=0.25.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.14.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.7.5)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (4.9.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.11/dist-packages (from jupyter-client>=6.1.12->ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.4)
# Requirement already satisfied: jupyter-events>=0.11.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (7.7.0)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (1.8.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.11/dist-packages (from argon2-cffi->notebook->jupyter<2.0.0,>=1.0.0->funpymodeling) (21.2.0)
# Requirement already satisfied: babel>=2.10 in /usr/local/lib/python3.11/dist-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.12.0)
# Requirement already satisfied: jsonschema>=4.18.0 in /usr/local/lib/python3.11/dist-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (4.23.0)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.11/dist-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (2.32.3)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.11/dist-packages (from nbformat>=5.7->nbconvert->jupyter<2.0.0,>=1.0.0->funpymodeling) (2.21.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->jupyter-console->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.2.13)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.11/dist-packages (from terminado>=0.8.3->notebook->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.7.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->nbconvert->jupyter<2.0.0,>=1.0.0->funpymodeling) (2.6)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx>=0.25.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (1.3.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.24.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.11/dist-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (3.3.0)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.11/dist-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (2.3.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter<2.0.0,>=1.0.0->funpymodeling) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter<2.0.0,>=1.0.0->funpymodeling) (2.22)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.11/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.11/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.11/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (3.0.0)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.11/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (24.11.1)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.11/dist-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /usr/local/lib/python3.11/dist-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (2.9.0.20241206)

# %% [markdown]
# #Importamos la librería de funpymodeling para explorar los datos

# %%
# status
from funpymodeling.exploratory import status

# %%
#Mostramos estadísticas del dataframe
status(d_star_wars)
# Out:
#      variable  q_nan     p_nan  q_zeros  p_zeros  unique     type
# 0        name      0  0.000000        0      0.0      87   object
# 1      height      6  0.068966        0      0.0      45  float64
# 2        mass     28  0.321839        0      0.0      38   object
# 3  hair_color      6  0.068966        0      0.0      11   object
# 4  skin_color      2  0.022989        0      0.0      30   object
# 5   eye_color      3  0.034483        0      0.0      14   object
# 6  birth_year     44  0.505747        0      0.0      36   object
# 7      gender      3  0.034483        0      0.0       4   object
# 8   homeworld     10  0.114943        0      0.0      48   object
# 9     species      5  0.057471        0      0.0      37   object

# %%
d_star_wars=pd.read_csv(filepath_or_buffer="https://raw.githubusercontent.com/fpineyro/homework-0/master/starwars.csv", sep=',')
d_star_wars
# Out:
#               name  height mass hair_color   skin_color eye_color birth_year  \
# 0   Luke Skywalker   172.0   77      blond         fair      blue      19BBY
# 1            C-3PO   167.0   75        NaN         gold    yellow     112BBY
# 2            R2-D2    96.0   32        NaN  white, blue       red      33BBY
# 3      Darth Vader   202.0  136       none        white    yellow    41.9BBY
# 4      Leia Organa   150.0   49      brown        light     brown      19BBY
# ..             ...     ...  ...        ...          ...       ...        ...
# 82             Rey     NaN  NaN      brown        light     hazel        NaN
# 83     Poe Dameron     NaN  NaN      brown        light     brown        NaN
# 84             BB8     NaN  NaN       none         none     black        NaN
# 85  Captain Phasma     NaN  NaN        NaN          NaN       NaN        NaN
# 86   Padmé Amidala   165.0   45      brown        light     brown      46BBY
#
#     gender homeworld species
# 0     male  Tatooine   Human
# 1      NaN  Tatooine   Droid
# 2      NaN     Naboo   Droid
# 3     male  Tatooine   Human
# 4   female  Alderaan   Human
# ..     ...       ...     ...
# 82  female       NaN   Human
# 83    male       NaN   Human
# 84    none       NaN   Droid
# 85  female       NaN     NaN
# 86  female     Naboo   Human
#
# [87 rows x 10 columns]

# %% [markdown]
# ## Nulos en pandas

# %%
d_star_wars.head()
# Out:
#              name  height mass hair_color   skin_color eye_color birth_year  \
# 0  Luke Skywalker   172.0   77      blond         fair      blue      19BBY
# 1           C-3PO   167.0   75        NaN         gold    yellow     112BBY
# 2           R2-D2    96.0   32        NaN  white, blue       red      33BBY
# 3     Darth Vader   202.0  136       none        white    yellow    41.9BBY
# 4     Leia Organa   150.0   49      brown        light     brown      19BBY
#
#    gender homeworld species
# 0    male  Tatooine   Human
# 1     NaN  Tatooine   Droid
# 2     NaN     Naboo   Droid
# 3    male  Tatooine   Human
# 4  female  Alderaan   Human

# %%
# None ~ NaN

# %%
status(d_star_wars)
# Out:
#      variable  q_nan     p_nan  q_zeros  p_zeros  unique     type
# 0        name      0  0.000000        0      0.0      87   object
# 1      height      6  0.068966        0      0.0      45  float64
# 2        mass     28  0.321839        0      0.0      38   object
# 3  hair_color      6  0.068966        0      0.0      11   object
# 4  skin_color      2  0.022989        0      0.0      30   object
# 5   eye_color      3  0.034483        0      0.0      14   object
# 6  birth_year     44  0.505747        0      0.0      36   object
# 7      gender      3  0.034483        0      0.0       4   object
# 8   homeworld     10  0.114943        0      0.0      48   object
# 9     species      5  0.057471        0      0.0      37   object

# %%
# obtener nulos de una columna
d_star_wars['hair_color'].isna()

# creamos un filtro para obtener los registros con valores nulos
d_star_wars[d_star_wars['hair_color'].isna()]
# Out:
#                      name  height   mass hair_color        skin_color  \
# 1                   C-3PO   167.0     75        NaN              gold
# 2                   R2-D2    96.0     32        NaN       white, blue
# 7                   R5-D4    97.0     32        NaN        white, red
# 14                 Greedo   173.0     74        NaN             green
# 15  Jabba Desilijic Tiure   175.0  1,358        NaN  green-tan, brown
# 85         Captain Phasma     NaN    NaN        NaN               NaN
#
#    eye_color birth_year         gender  homeworld species
# 1     yellow     112BBY            NaN   Tatooine   Droid
# 2        red      33BBY            NaN      Naboo   Droid
# 7        red        NaN            NaN   Tatooine   Droid
# 14     black      44BBY           male      Rodia  Rodian
# 15    orange     600BBY  hermaphrodite  Nal Hutta    Hutt
# 85       NaN        NaN         female        NaN     NaN

# %%
# el origen de los NaN
import numpy as np

# %%
a=pd.Series([1,2,3,"np.NaN"])

# %%
b=pd.Series([1,2,3, None])

# %%
a
# Out:
# 0         1
# 1         2
# 2         3
# 3    np.NaN
# dtype: object

# %%
b
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# dtype: float64

# %% [markdown]
# ### Remplazo de nulos
#
# Variable categórica / object

# %%
d_star_wars
# Out:
#               name  height mass hair_color   skin_color eye_color birth_year  \
# 0   Luke Skywalker   172.0   77      blond         fair      blue      19BBY
# 1            C-3PO   167.0   75        NaN         gold    yellow     112BBY
# 2            R2-D2    96.0   32        NaN  white, blue       red      33BBY
# 3      Darth Vader   202.0  136       none        white    yellow    41.9BBY
# 4      Leia Organa   150.0   49      brown        light     brown      19BBY
# ..             ...     ...  ...        ...          ...       ...        ...
# 82             Rey     NaN  NaN      brown        light     hazel        NaN
# 83     Poe Dameron     NaN  NaN      brown        light     brown        NaN
# 84             BB8     NaN  NaN       none         none     black        NaN
# 85  Captain Phasma     NaN  NaN        NaN          NaN       NaN        NaN
# 86   Padmé Amidala   165.0   45      brown        light     brown      46BBY
#
#     gender homeworld species
# 0     male  Tatooine   Human
# 1      NaN  Tatooine   Droid
# 2      NaN     Naboo   Droid
# 3     male  Tatooine   Human
# 4   female  Alderaan   Human
# ..     ...       ...     ...
# 82  female       NaN   Human
# 83    male       NaN   Human
# 84    none       NaN   Droid
# 85  female       NaN     NaN
# 86  female     Naboo   Human
#
# [87 rows x 10 columns]

# %%
values={'homeworld': 'nulo_home', 'species': 'nulo_species'}

d_star_wars.fillna(value=values)
# Out:
#               name  height mass hair_color   skin_color eye_color birth_year  \
# 0   Luke Skywalker   172.0   77      blond         fair      blue      19BBY
# 1            C-3PO   167.0   75        NaN         gold    yellow     112BBY
# 2            R2-D2    96.0   32        NaN  white, blue       red      33BBY
# 3      Darth Vader   202.0  136       none        white    yellow    41.9BBY
# 4      Leia Organa   150.0   49      brown        light     brown      19BBY
# ..             ...     ...  ...        ...          ...       ...        ...
# 82             Rey     NaN  NaN      brown        light     hazel        NaN
# 83     Poe Dameron     NaN  NaN      brown        light     brown        NaN
# 84             BB8     NaN  NaN       none         none     black        NaN
# 85  Captain Phasma     NaN  NaN        NaN          NaN       NaN        NaN
# 86   Padmé Amidala   165.0   45      brown        light     brown      46BBY
#
#     gender  homeworld       species
# 0     male   Tatooine         Human
# 1      NaN   Tatooine         Droid
# 2      NaN      Naboo         Droid
# 3     male   Tatooine         Human
# 4   female   Alderaan         Human
# ..     ...        ...           ...
# 82  female  nulo_home         Human
# 83    male  nulo_home         Human
# 84    none  nulo_home         Droid
# 85  female  nulo_home  nulo_species
# 86  female      Naboo         Human
#
# [87 rows x 10 columns]

# %%
# remplazo en el mismo data frame
d_star_wars.fillna(value=values, inplace=True)

# %%
d_star_wars
# Out:
#               name  height mass hair_color   skin_color eye_color birth_year  \
# 0   Luke Skywalker   172.0   77      blond         fair      blue      19BBY
# 1            C-3PO   167.0   75        NaN         gold    yellow     112BBY
# 2            R2-D2    96.0   32        NaN  white, blue       red      33BBY
# 3      Darth Vader   202.0  136       none        white    yellow    41.9BBY
# 4      Leia Organa   150.0   49      brown        light     brown      19BBY
# ..             ...     ...  ...        ...          ...       ...        ...
# 82             Rey     NaN  NaN      brown        light     hazel        NaN
# 83     Poe Dameron     NaN  NaN      brown        light     brown        NaN
# 84             BB8     NaN  NaN       none         none     black        NaN
# 85  Captain Phasma     NaN  NaN        NaN          NaN       NaN        NaN
# 86   Padmé Amidala   165.0   45      brown        light     brown      46BBY
#
#     gender  homeworld       species
# 0     male   Tatooine         Human
# 1      NaN   Tatooine         Droid
# 2      NaN      Naboo         Droid
# 3     male   Tatooine         Human
# 4   female   Alderaan         Human
# ..     ...        ...           ...
# 82  female  nulo_home         Human
# 83    male  nulo_home         Human
# 84    none  nulo_home         Droid
# 85  female  nulo_home  nulo_species
# 86  female      Naboo         Human
#
# [87 rows x 10 columns]

# %% [markdown]
# ## Imputación de nulos para variables numéricas

# %%
# Obtención del promedio de la altura, y luego imputamos una columna
d_star_wars['height'].mean()
# Out:
# np.float64(174.35802469135803)

# %%
d_star_wars['height']=d_star_wars['height'].fillna(d_star_wars['height'].mean())

d_star_wars
# Out:
#               name      height mass hair_color   skin_color eye_color  \
# 0   Luke Skywalker  172.000000   77      blond         fair      blue
# 1            C-3PO  167.000000   75        NaN         gold    yellow
# 2            R2-D2   96.000000   32        NaN  white, blue       red
# 3      Darth Vader  202.000000  136       none        white    yellow
# 4      Leia Organa  150.000000   49      brown        light     brown
# ..             ...         ...  ...        ...          ...       ...
# 82             Rey  174.358025  NaN      brown        light     hazel
# 83     Poe Dameron  174.358025  NaN      brown        light     brown
# 84             BB8  174.358025  NaN       none         none     black
# 85  Captain Phasma  174.358025  NaN        NaN          NaN       NaN
# 86   Padmé Amidala  165.000000   45      brown        light     brown
#
#    birth_year  gender  homeworld       species
# 0       19BBY    male   Tatooine         Human
# 1      112BBY     NaN   Tatooine         Droid
# 2       33BBY     NaN      Naboo         Droid
# 3     41.9BBY    male   Tatooine         Human
# 4       19BBY  female   Alderaan         Human
# ..        ...     ...        ...           ...
# 82        NaN  female  nulo_home         Human
# 83        NaN    male  nulo_home         Human
# 84        NaN    none  nulo_home         Droid
# 85        NaN  female  nulo_home  nulo_species
# 86      46BBY  female      Naboo         Human
#
# [87 rows x 10 columns]

# %% [markdown]
# ---
#
# ## Ejercicios!
#
# Se asume que ya corrieron los ejercicios mostrados y exploraron un poco el ecosistema de google colab.
#
# 👉 **Es super importante** que los hagan para fijar lo que aprendieron. No se frusten si estan 20 minutos para crear una lista, es al principio!
#
# <br>
#
# 1) Crear dos listas de 5 valores, uno númerico y otro con string, llamado lista1 y lista2, con los siguientes valores:
#
# 1,2,3,4,5
#
# a,b,c,d,e

# %%
#Ejercicio 1

lista1 = [1,2,3,4,5]
lista2 = ['a','b','c','d','e']

# %%
lista1
# Out:
# [1, 2, 3, 4, 5]

# %%
lista2
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %% [markdown]
# 2) Crear e imprimir en pantalla un pandas data frame llamado `d_test` basandose en las listas del punto 1). Nombres de las columnas: `columna_A` y `columna_B`

# %%
#Ejercicio 2
d_test = pd.DataFrame({'columna_A','columna_B'})

# %%
d_test
# Out:
#            0
# 0  columna_A
# 1  columna_B

# %% [markdown]
# 3) Cargar los datos de heart disease con pandas en una variable llamada `d_hd`. Imprimir en pantalla.
#
# URL: `https://raw.githubusercontent.com/fpineyro/homework-0/master/heart_disease.csv`

# %%
#Ejercicio 3
d_hd = pd.read_csv('https://raw.githubusercontent.com/fpineyro/homework-0/master/heart_disease.csv')
d_hd
# Out:
#      age  gender  chest_pain  resting_blood_pressure  serum_cholestoral  \
# 0     63    male           1                     145                233
# 1     67    male           4                     160                286
# 2     67    male           4                     120                229
# 3     37    male           3                     130                250
# 4     41  female           2                     130                204
# ..   ...     ...         ...                     ...                ...
# 298   45    male           1                     110                264
# 299   68    male           4                     144                193
# 300   57    male           4                     130                131
# 301   57  female           2                     130                236
# 302   38    male           3                     138                175
#
#      fasting_blood_sugar  resting_electro  max_heart_rate  exer_angina  \
# 0                      1                2             150            0
# 1                      0                2             108            1
# 2                      0                2             129            1
# 3                      0                0             187            0
# 4                      0                2             172            0
# ..                   ...              ...             ...          ...
# 298                    0                0             132            0
# 299                    1                0             141            0
# 300                    0                0             115            1
# 301                    0                2             174            0
# 302                    0                0             173            0
#
#      oldpeak  slope  num_vessels_flour  thal  heart_disease_severity  \
# 0        2.3      3                0.0   6.0                       0
# 1        1.5      2                3.0   3.0                       2
# 2        2.6      2                2.0   7.0                       1
# 3        3.5      3                0.0   3.0                       0
# 4        1.4      1                0.0   3.0                       0
# ..       ...    ...                ...   ...                     ...
# 298      1.2      2                0.0   7.0                       1
# 299      3.4      2                2.0   7.0                       2
# 300      1.2      2                1.0   7.0                       3
# 301      0.0      2                1.0   3.0                       1
# 302      0.0      1                NaN   3.0                       0
#
#      exter_angina has_heart_disease
# 0               0                no
# 1               1               yes
# 2               1               yes
# 3               0                no
# 4               0                no
# ..            ...               ...
# 298             0               yes
# 299             0               yes
# 300             1               yes
# 301             0               yes
# 302             0                no
#
# [303 rows x 16 columns]

# %%
#Ejercicio 3.1) Imprimir la variable `age` y `has_heart_disease` al mismo tiempo.
d_hd[['age','has_heart_disease']]
# Out:
#      age has_heart_disease
# 0     63                no
# 1     67               yes
# 2     67               yes
# 3     37                no
# 4     41                no
# ..   ...               ...
# 298   45               yes
# 299   68               yes
# 300   57               yes
# 301   57               yes
# 302   38                no
#
# [303 rows x 2 columns]

# %%
#Ejericio 3.2) Explorar los datos con DataTable de google colab, usar filtros y ordenar las columnas haciendo click en ellas
from google.colab.data_table import DataTable

DataTable(d_hd)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>age</th>
#       <th>gender</th>
#       <th>chest_pain</th>
#       <th>resting_blood_pressure</th>
#       <th>serum_cholestoral</th>
#       <th>fasting_blood_sugar</th>
#       <th>resting_electro</th>
#       <th>max_heart_rate</th>
#       <th>exer_angina</th>
#       <th>oldpeak</th>
#       <th>slope</th>
#       <th>num_vessels_flour</th>
#       <th>thal</th>
#       <th>heart_disease_severity</th>
#       <th>exter_angina</th>
#       <th>has_heart_disease</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>63</td>
#       <td>male</td>
#       <td>1</td>
#       <td>145</td>
#       <td>233</td>
#       <td>1</td>
#       <td>2</td>
#       <td>150</td>
#       <td>0</td>
#       <td>2.3</td>
#       <td>3</td>
#       <td>0.0</td>
#       <td>6.0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>no</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>67</td>
#       <td>male</td>
#       <td>4</td>
#       <td>160</td>
#       <td>286</td>
#       <td>0</td>
#       <td>2</td>
#       <td>108</td>
#       <td>1</td>
#       <td>1.5</td>
#       <td>2</td>
#       <td>3.0</td>
#       <td>3.0</td>
#       <td>2</td>
#       <td>1</td>
#       <td>yes</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>67</td>
#       <td>male</td>
#       <td>4</td>
#       <td>120</td>
#       <td>229</td>
#       <td>0</td>
#       <td>2</td>
#       <td>129</td>
#       <td>1</td>
#       <td>2.6</td>
#       <td>2</td>
#       <td>2.0</td>
#       <td>7.0</td>
#       <td>1</td>
#       <td>1</td>
#       <td>yes</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>37</td>
#       <td>male</td>
#       <td>3</td>
#       <td>130</td>
#       <td>250</td>
#       <td>0</td>
#       <td>0</td>
#       <td>187</td>
#       <td>0</td>
#       <td>3.5</td>
#       <td>3</td>
#       <td>0.0</td>
#       <td>3.0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>no</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>41</td>
#       <td>female</td>
#       <td>2</td>
#       <td>130</td>
#       <td>204</td>
#       <td>0</td>
#       <td>2</td>
#       <td>172</td>
#       <td>0</td>
#       <td>1.4</td>
#       <td>1</td>
#       <td>0.0</td>
#       <td>3.0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>no</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>298</th>
#       <td>45</td>
#       <td>male</td>
#       <td>1</td>
#       <td>110</td>
#       <td>264</td>
#       <td>0</td>
#       <td>0</td>
#       <td>132</td>
#       <td>0</td>
#       <td>1.2</td>
#       <td>2</td>
#       <td>0.0</td>
#       <td>7.0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>yes</td>
#     </tr>
#     <tr>
#       <th>299</th>
#       <td>68</td>
#       <td>male</td>
#       <td>4</td>
#       <td>144</td>
#       <td>193</td>
#       <td>1</td>
#       <td>0</td>
#       <td>141</td>
#       <td>0</td>
#       <td>3.4</td>
#       <td>2</td>
#       <td>2.0</td>
#       <td>7.0</td>
#       <td>2</td>
#       <td>0</td>
#       <td>yes</td>
#     </tr>
#     <tr>
#       <th>300</th>
#       <td>57</td>
#       <td>male</td>
#       <td>4</td>
#       <td>130</td>
#       <td>131</td>
#       <td>0</td>
#       <td>0</td>
#       <td>115</td>
#       <td>1</td>
#       <td>1.2</td>
#       <td>2</td>
#       <td>1.0</td>
#       <td>7.0</td>
#       <td>3</td>
#       <td>1</td>
#       <td>yes</td>
#     </tr>
#     <tr>
#       <th>301</th>
#       <td>57</td>
#       <td>female</td>
#       <td>2</td>
#       <td>130</td>
#       <td>236</td>
#       <td>0</td>
#       <td>2</td>
#       <td>174</td>
#       <td>0</td>
#       <td>0.0</td>
#       <td>2</td>
#       <td>1.0</td>
#       <td>3.0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>yes</td>
#     </tr>
#     <tr>
#       <th>302</th>
#       <td>38</td>
#       <td>male</td>
#       <td>3</td>
#       <td>138</td>
#       <td>175</td>
#       <td>0</td>
#       <td>0</td>
#       <td>173</td>
#       <td>0</td>
#       <td>0.0</td>
#       <td>1</td>
#       <td>NaN</td>
#       <td>3.0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>no</td>
#     </tr>
#   </tbody>
# </table>
# <p>303 rows × 16 columns</p>
# </div>

# %%
#Ejercicio 3.3) Imprimir los primeros 3 registros con head, y los últomos 3 con tail

# head
d_hd.head(3)
# Out:
#    age gender  chest_pain  resting_blood_pressure  serum_cholestoral  \
# 0   63   male           1                     145                233
# 1   67   male           4                     160                286
# 2   67   male           4                     120                229
#
#    fasting_blood_sugar  resting_electro  max_heart_rate  exer_angina  oldpeak  \
# 0                    1                2             150            0      2.3
# 1                    0                2             108            1      1.5
# 2                    0                2             129            1      2.6
#
#    slope  num_vessels_flour  thal  heart_disease_severity  exter_angina  \
# 0      3                0.0   6.0                       0             0
# 1      2                3.0   3.0                       2             1
# 2      2                2.0   7.0                       1             1
#
#   has_heart_disease
# 0                no
# 1               yes
# 2               yes

# %%
#tail
d_hd.tail(3)
# Out:
#      age  gender  chest_pain  resting_blood_pressure  serum_cholestoral  \
# 300   57    male           4                     130                131
# 301   57  female           2                     130                236
# 302   38    male           3                     138                175
#
#      fasting_blood_sugar  resting_electro  max_heart_rate  exer_angina  \
# 300                    0                0             115            1
# 301                    0                2             174            0
# 302                    0                0             173            0
#
#      oldpeak  slope  num_vessels_flour  thal  heart_disease_severity  \
# 300      1.2      2                1.0   7.0                       3
# 301      0.0      2                1.0   3.0                       1
# 302      0.0      1                NaN   3.0                       0
#
#      exter_angina has_heart_disease
# 300             1               yes
# 301             0               yes
# 302             0                no

# %%
#Ejercicio 3.4) Acceder con loc a la columna has_heart_disease, y mostrar todos los registros
d_hd.loc[:,'has_heart_disease']
# Out:
# 0       no
# 1      yes
# 2      yes
# 3       no
# 4       no
#       ...
# 298    yes
# 299    yes
# 300    yes
# 301    yes
# 302     no
# Name: has_heart_disease, Length: 303, dtype: object

# %%
#Ejercicio 3.5) Idem 3.4) peor mostrando los primeros 3 registros. Usar slice, no head.
d_hd.loc[0:3,'has_heart_disease']
# Out:
# 0     no
# 1    yes
# 2    yes
# 3     no
# Name: has_heart_disease, dtype: object

# %%
#Ejercicio 3.6) Usar iloc para obtener las primeras 3 columnas, y 5 registros
d_hd.iloc[0:3,0:5]
# Out:
#    age gender  chest_pain  resting_blood_pressure  serum_cholestoral
# 0   63   male           1                     145                233
# 1   67   male           4                     160                286
# 2   67   male           4                     120                229

# %% [markdown]
# 4) Trabajando con nulos

# %%
# 4.1) Instalar funpymodeling
# !pip install funpymodeling
# Out:
# Requirement already satisfied: funpymodeling in /usr/local/lib/python3.11/dist-packages (0.1.9)
# Requirement already satisfied: flake8<7.0.0,>=6.0.0 in /usr/local/lib/python3.11/dist-packages (from funpymodeling) (6.1.0)
# Requirement already satisfied: jupyter<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from funpymodeling) (1.1.1)
# Requirement already satisfied: matplotlib<4.0.0,>=3.7.1 in /usr/local/lib/python3.11/dist-packages (from funpymodeling) (3.10.0)
# Requirement already satisfied: numpy<2.0.0,>=1.26.2 in /usr/local/lib/python3.11/dist-packages (from funpymodeling) (1.26.4)
# Requirement already satisfied: pandas<3.0.0,>=2.1.4 in /usr/local/lib/python3.11/dist-packages (from funpymodeling) (2.2.2)
# Requirement already satisfied: pre-commit<4.0.0,>=3.3.2 in /usr/local/lib/python3.11/dist-packages (from funpymodeling) (3.8.0)
# Requirement already satisfied: pytest<8.0.0,>=7.3.1 in /usr/local/lib/python3.11/dist-packages (from funpymodeling) (7.4.4)
# Requirement already satisfied: scikit-learn<2.0.0,>=1.2.2 in /usr/local/lib/python3.11/dist-packages (from funpymodeling) (1.6.1)
# Requirement already satisfied: seaborn<0.13.0,>=0.12.2 in /usr/local/lib/python3.11/dist-packages (from funpymodeling) (0.12.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.6.3 in /usr/local/lib/python3.11/dist-packages (from funpymodeling) (4.13.1)
# Requirement already satisfied: mccabe<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from flake8<7.0.0,>=6.0.0->funpymodeling) (0.7.0)
# Requirement already satisfied: pycodestyle<2.12.0,>=2.11.0 in /usr/local/lib/python3.11/dist-packages (from flake8<7.0.0,>=6.0.0->funpymodeling) (2.11.1)
# Requirement already satisfied: pyflakes<3.2.0,>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from flake8<7.0.0,>=6.0.0->funpymodeling) (3.1.0)
# Requirement already satisfied: notebook in /usr/local/lib/python3.11/dist-packages (from jupyter<2.0.0,>=1.0.0->funpymodeling) (6.5.7)
# Requirement already satisfied: jupyter-console in /usr/local/lib/python3.11/dist-packages (from jupyter<2.0.0,>=1.0.0->funpymodeling) (6.1.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.11/dist-packages (from jupyter<2.0.0,>=1.0.0->funpymodeling) (7.16.6)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.11/dist-packages (from jupyter<2.0.0,>=1.0.0->funpymodeling) (6.17.1)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.11/dist-packages (from jupyter<2.0.0,>=1.0.0->funpymodeling) (7.7.1)
# Requirement already satisfied: jupyterlab in /usr/local/lib/python3.11/dist-packages (from jupyter<2.0.0,>=1.0.0->funpymodeling) (4.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4.0.0,>=3.7.1->funpymodeling) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4.0.0,>=3.7.1->funpymodeling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4.0.0,>=3.7.1->funpymodeling) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4.0.0,>=3.7.1->funpymodeling) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4.0.0,>=3.7.1->funpymodeling) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4.0.0,>=3.7.1->funpymodeling) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4.0.0,>=3.7.1->funpymodeling) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4.0.0,>=3.7.1->funpymodeling) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<3.0.0,>=2.1.4->funpymodeling) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<3.0.0,>=2.1.4->funpymodeling) (2025.2)
# Requirement already satisfied: cfgv>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from pre-commit<4.0.0,>=3.3.2->funpymodeling) (3.4.0)
# Requirement already satisfied: identify>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from pre-commit<4.0.0,>=3.3.2->funpymodeling) (2.6.9)
# Requirement already satisfied: nodeenv>=0.11.1 in /usr/local/lib/python3.11/dist-packages (from pre-commit<4.0.0,>=3.3.2->funpymodeling) (1.9.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from pre-commit<4.0.0,>=3.3.2->funpymodeling) (6.0.2)
# Requirement already satisfied: virtualenv>=20.10.0 in /usr/local/lib/python3.11/dist-packages (from pre-commit<4.0.0,>=3.3.2->funpymodeling) (20.30.0)
# Requirement already satisfied: iniconfig in /usr/local/lib/python3.11/dist-packages (from pytest<8.0.0,>=7.3.1->funpymodeling) (2.1.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /usr/local/lib/python3.11/dist-packages (from pytest<8.0.0,>=7.3.1->funpymodeling) (1.5.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<2.0.0,>=1.2.2->funpymodeling) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<2.0.0,>=1.2.2->funpymodeling) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<2.0.0,>=1.2.2->funpymodeling) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib<4.0.0,>=3.7.1->funpymodeling) (1.17.0)
# Requirement already satisfied: distlib<1,>=0.3.7 in /usr/local/lib/python3.11/dist-packages (from virtualenv>=20.10.0->pre-commit<4.0.0,>=3.3.2->funpymodeling) (0.3.9)
# Requirement already satisfied: filelock<4,>=3.12.2 in /usr/local/lib/python3.11/dist-packages (from virtualenv>=20.10.0->pre-commit<4.0.0,>=3.3.2->funpymodeling) (3.18.0)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in /usr/local/lib/python3.11/dist-packages (from virtualenv>=20.10.0->pre-commit<4.0.0,>=3.3.2->funpymodeling) (4.3.7)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.11/dist-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (1.8.0)
# Requirement already satisfied: ipython>=7.23.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (7.34.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.11/dist-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (7.4.9)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.1.7)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.11/dist-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (1.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (5.9.5)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.11/dist-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (24.0.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (6.4.2)
# Requirement already satisfied: traitlets>=5.1.0 in /usr/local/lib/python3.11/dist-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (5.7.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets->jupyter<2.0.0,>=1.0.0->funpymodeling) (3.6.10)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets->jupyter<2.0.0,>=1.0.0->funpymodeling) (3.0.13)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-console->jupyter<2.0.0,>=1.0.0->funpymodeling) (3.0.50)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from jupyter-console->jupyter<2.0.0,>=1.0.0->funpymodeling) (2.18.0)
# Requirement already satisfied: async-lru>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (2.0.5)
# Requirement already satisfied: httpx>=0.25.0 in /usr/local/lib/python3.11/dist-packages (from jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.28.1)
# Requirement already satisfied: jinja2>=3.0.3 in /usr/local/lib/python3.11/dist-packages (from jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (3.1.6)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.11/dist-packages (from jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (5.7.2)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (2.2.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (2.15.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /usr/local/lib/python3.11/dist-packages (from jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in /usr/local/lib/python3.11/dist-packages (from jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.2.4)
# Requirement already satisfied: setuptools>=41.1.0 in /usr/local/lib/python3.11/dist-packages (from jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (75.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->funpymodeling) (4.13.3)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert->jupyter<2.0.0,>=1.0.0->funpymodeling) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.11/dist-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.11/dist-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->funpymodeling) (3.0.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.11/dist-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->funpymodeling) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.10.2)
# Requirement already satisfied: nbformat>=5.7 in /usr/local/lib/python3.11/dist-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->funpymodeling) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->funpymodeling) (1.5.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.11/dist-packages (from notebook->jupyter<2.0.0,>=1.0.0->funpymodeling) (23.1.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from notebook->jupyter<2.0.0,>=1.0.0->funpymodeling) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.11/dist-packages (from notebook->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.11/dist-packages (from notebook->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.21.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.11/dist-packages (from notebook->jupyter<2.0.0,>=1.0.0->funpymodeling) (1.2.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert->jupyter<2.0.0,>=1.0.0->funpymodeling) (1.4.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx>=0.25.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (4.9.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx>=0.25.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.25.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (1.0.7)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx>=0.25.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.14.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.7.5)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (4.9.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.11/dist-packages (from jupyter-client>=6.1.12->ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.4)
# Requirement already satisfied: jupyter-events>=0.11.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (7.7.0)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (1.8.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.11/dist-packages (from argon2-cffi->notebook->jupyter<2.0.0,>=1.0.0->funpymodeling) (21.2.0)
# Requirement already satisfied: babel>=2.10 in /usr/local/lib/python3.11/dist-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.12.0)
# Requirement already satisfied: jsonschema>=4.18.0 in /usr/local/lib/python3.11/dist-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (4.23.0)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.11/dist-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (2.32.3)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.11/dist-packages (from nbformat>=5.7->nbconvert->jupyter<2.0.0,>=1.0.0->funpymodeling) (2.21.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->jupyter-console->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.2.13)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.11/dist-packages (from terminado>=0.8.3->notebook->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.7.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->nbconvert->jupyter<2.0.0,>=1.0.0->funpymodeling) (2.6)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx>=0.25.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (1.3.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.24.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.11/dist-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (3.3.0)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.11/dist-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (0.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (2.3.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter<2.0.0,>=1.0.0->funpymodeling) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter<2.0.0,>=1.0.0->funpymodeling) (2.22)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.11/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.11/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.11/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (3.0.0)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.11/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (24.11.1)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.11/dist-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /usr/local/lib/python3.11/dist-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->funpymodeling) (2.9.0.20241206)

# %%
# 4.2) Cargar función status
from funpymodeling.exploratory import status

# %%
#Ejercicio 4.3) ¿Qué variables tienen nulos?  (usar status)

status(d_hd)
# Out:
#                   variable  q_nan     p_nan  q_zeros   p_zeros  unique  \
# 0                      age      0  0.000000        0  0.000000      41
# 1                   gender      0  0.000000        0  0.000000       2
# 2               chest_pain      0  0.000000        0  0.000000       4
# 3   resting_blood_pressure      0  0.000000        0  0.000000      50
# 4        serum_cholestoral      0  0.000000        0  0.000000     152
# 5      fasting_blood_sugar      0  0.000000      258  0.851485       2
# 6          resting_electro      0  0.000000      151  0.498350       3
# 7           max_heart_rate      0  0.000000        0  0.000000      91
# 8              exer_angina      0  0.000000      204  0.673267       2
# 9                  oldpeak      0  0.000000       99  0.326733      40
# 10                   slope      0  0.000000        0  0.000000       3
# 11       num_vessels_flour      4  0.013201      176  0.580858       4
# 12                    thal      2  0.006601        0  0.000000       3
# 13  heart_disease_severity      0  0.000000      164  0.541254       5
# 14            exter_angina      0  0.000000      204  0.673267       2
# 15       has_heart_disease      0  0.000000        0  0.000000       2
#
#        type
# 0     int64
# 1    object
# 2     int64
# 3     int64
# 4     int64
# 5     int64
# 6     int64
# 7     int64
# 8     int64
# 9   float64
# 10    int64
# 11  float64
# 12  float64
# 13    int64
# 14    int64
# 15   object

# %%
#Ejercicio 4.4) Devolver un data frame con todos los registros que tienen NaN en la variable "thal".
d_hd[d_hd['thal'].isna()]
# Out:
#      age  gender  chest_pain  resting_blood_pressure  serum_cholestoral  \
# 87    53  female           3                     128                216
# 266   52    male           4                     128                204
#
#      fasting_blood_sugar  resting_electro  max_heart_rate  exer_angina  \
# 87                     0                2             115            0
# 266                    1                0             156            1
#
#      oldpeak  slope  num_vessels_flour  thal  heart_disease_severity  \
# 87       0.0      1                0.0   NaN                       0
# 266      1.0      2                0.0   NaN                       2
#
#      exter_angina has_heart_disease
# 87              0                no
# 266             1               yes

# %%
#Ejercicio 4.5) Remplazar los nulos que aparecen en la variable "thal por 999. *No* guardarlo en el dataframe original. Usar fillna.
values={'thal':'999'}

d_hd.fillna(value=values)
# Out:
#      age  gender  chest_pain  resting_blood_pressure  serum_cholestoral  \
# 0     63    male           1                     145                233
# 1     67    male           4                     160                286
# 2     67    male           4                     120                229
# 3     37    male           3                     130                250
# 4     41  female           2                     130                204
# ..   ...     ...         ...                     ...                ...
# 298   45    male           1                     110                264
# 299   68    male           4                     144                193
# 300   57    male           4                     130                131
# 301   57  female           2                     130                236
# 302   38    male           3                     138                175
#
#      fasting_blood_sugar  resting_electro  max_heart_rate  exer_angina  \
# 0                      1                2             150            0
# 1                      0                2             108            1
# 2                      0                2             129            1
# 3                      0                0             187            0
# 4                      0                2             172            0
# ..                   ...              ...             ...          ...
# 298                    0                0             132            0
# 299                    1                0             141            0
# 300                    0                0             115            1
# 301                    0                2             174            0
# 302                    0                0             173            0
#
#      oldpeak  slope  num_vessels_flour thal  heart_disease_severity  \
# 0        2.3      3                0.0  6.0                       0
# 1        1.5      2                3.0  3.0                       2
# 2        2.6      2                2.0  7.0                       1
# 3        3.5      3                0.0  3.0                       0
# 4        1.4      1                0.0  3.0                       0
# ..       ...    ...                ...  ...                     ...
# 298      1.2      2                0.0  7.0                       1
# 299      3.4      2                2.0  7.0                       2
# 300      1.2      2                1.0  7.0                       3
# 301      0.0      2                1.0  3.0                       1
# 302      0.0      1                NaN  3.0                       0
#
#      exter_angina has_heart_disease
# 0               0                no
# 1               1               yes
# 2               1               yes
# 3               0                no
# 4               0                no
# ..            ...               ...
# 298             0               yes
# 299             0               yes
# 300             1               yes
# 301             0               yes
# 302             0                no
#
# [303 rows x 16 columns]

# %%
#Ejercicio 4.6) Remplazar los nulos que aparecen en la variable "thal" por 999 (como antes),
# y también remplazar los nulos de "num_vessels_flour" por el promedio de la variable.
# Guardar el resultado en un dataframe nuevo llamado "d_hd2".

values={'thal':'999', 'num_vessels_flour':d_hd['num_vessels_flour'].mean()}

d_hd2=d_hd.fillna(value=values)

d_hd2
# Out:
#      age  gender  chest_pain  resting_blood_pressure  serum_cholestoral  \
# 0     63    male           1                     145                233
# 1     67    male           4                     160                286
# 2     67    male           4                     120                229
# 3     37    male           3                     130                250
# 4     41  female           2                     130                204
# ..   ...     ...         ...                     ...                ...
# 298   45    male           1                     110                264
# 299   68    male           4                     144                193
# 300   57    male           4                     130                131
# 301   57  female           2                     130                236
# 302   38    male           3                     138                175
#
#      fasting_blood_sugar  resting_electro  max_heart_rate  exer_angina  \
# 0                      1                2             150            0
# 1                      0                2             108            1
# 2                      0                2             129            1
# 3                      0                0             187            0
# 4                      0                2             172            0
# ..                   ...              ...             ...          ...
# 298                    0                0             132            0
# 299                    1                0             141            0
# 300                    0                0             115            1
# 301                    0                2             174            0
# 302                    0                0             173            0
#
#      oldpeak  slope  num_vessels_flour thal  heart_disease_severity  \
# 0        2.3      3           0.000000  6.0                       0
# 1        1.5      2           3.000000  3.0                       2
# 2        2.6      2           2.000000  7.0                       1
# 3        3.5      3           0.000000  3.0                       0
# 4        1.4      1           0.000000  3.0                       0
# ..       ...    ...                ...  ...                     ...
# 298      1.2      2           0.000000  7.0                       1
# 299      3.4      2           2.000000  7.0                       2
# 300      1.2      2           1.000000  7.0                       3
# 301      0.0      2           1.000000  3.0                       1
# 302      0.0      1           0.672241  3.0                       0
#
#      exter_angina has_heart_disease
# 0               0                no
# 1               1               yes
# 2               1               yes
# 3               0                no
# 4               0                no
# ..            ...               ...
# 298             0               yes
# 299             0               yes
# 300             1               yes
# 301             0               yes
# 302             0                no
#
# [303 rows x 16 columns]

# %%
#Ejercicio 4.7) Chequear resultado con status
status(d_hd)
# Out:
#                   variable  q_nan     p_nan  q_zeros   p_zeros  unique  \
# 0                      age      0  0.000000        0  0.000000      41
# 1                   gender      0  0.000000        0  0.000000       2
# 2               chest_pain      0  0.000000        0  0.000000       4
# 3   resting_blood_pressure      0  0.000000        0  0.000000      50
# 4        serum_cholestoral      0  0.000000        0  0.000000     152
# 5      fasting_blood_sugar      0  0.000000      258  0.851485       2
# 6          resting_electro      0  0.000000      151  0.498350       3
# 7           max_heart_rate      0  0.000000        0  0.000000      91
# 8              exer_angina      0  0.000000      204  0.673267       2
# 9                  oldpeak      0  0.000000       99  0.326733      40
# 10                   slope      0  0.000000        0  0.000000       3
# 11       num_vessels_flour      4  0.013201      176  0.580858       4
# 12                    thal      2  0.006601        0  0.000000       3
# 13  heart_disease_severity      0  0.000000      164  0.541254       5
# 14            exter_angina      0  0.000000      204  0.673267       2
# 15       has_heart_disease      0  0.000000        0  0.000000       2
#
#        type
# 0     int64
# 1    object
# 2     int64
# 3     int64
# 4     int64
# 5     int64
# 6     int64
# 7     int64
# 8     int64
# 9   float64
# 10    int64
# 11  float64
# 12  float64
# 13    int64
# 14    int64
# 15   object

# %%
#Ejercicio 4.8)
# Eliminar todas los registros con nulos usando `dropna` de pandas

d_hd.dropna()
# Out:
#      age  gender  chest_pain  resting_blood_pressure  serum_cholestoral  \
# 0     63    male           1                     145                233
# 1     67    male           4                     160                286
# 2     67    male           4                     120                229
# 3     37    male           3                     130                250
# 4     41  female           2                     130                204
# ..   ...     ...         ...                     ...                ...
# 297   57  female           4                     140                241
# 298   45    male           1                     110                264
# 299   68    male           4                     144                193
# 300   57    male           4                     130                131
# 301   57  female           2                     130                236
#
#      fasting_blood_sugar  resting_electro  max_heart_rate  exer_angina  \
# 0                      1                2             150            0
# 1                      0                2             108            1
# 2                      0                2             129            1
# 3                      0                0             187            0
# 4                      0                2             172            0
# ..                   ...              ...             ...          ...
# 297                    0                0             123            1
# 298                    0                0             132            0
# 299                    1                0             141            0
# 300                    0                0             115            1
# 301                    0                2             174            0
#
#      oldpeak  slope  num_vessels_flour  thal  heart_disease_severity  \
# 0        2.3      3                0.0   6.0                       0
# 1        1.5      2                3.0   3.0                       2
# 2        2.6      2                2.0   7.0                       1
# 3        3.5      3                0.0   3.0                       0
# 4        1.4      1                0.0   3.0                       0
# ..       ...    ...                ...   ...                     ...
# 297      0.2      2                0.0   7.0                       1
# 298      1.2      2                0.0   7.0                       1
# 299      3.4      2                2.0   7.0                       2
# 300      1.2      2                1.0   7.0                       3
# 301      0.0      2                1.0   3.0                       1
#
#      exter_angina has_heart_disease
# 0               0                no
# 1               1               yes
# 2               1               yes
# 3               0                no
# 4               0                no
# ..            ...               ...
# 297             1               yes
# 298             0               yes
# 299             0               yes
# 300             1               yes
# 301             0               yes
#
# [297 rows x 16 columns]
